# %%
import cv2
import pandas as pd
from ultralytics import YOLO
import cvzone
import numpy as np

# %%
# ✅ Load the YOLO model correctly using Ultralytics
model = YOLO(r"D:\Model\helmet detection\best.pt")  # Do NOT use torch.load here

# ✅ Manually define class names (example: helmet detection)
class_list = ['helmet']  # <-- Replace with your actual class names

def RGB(event, x, y, flags, param):
    if event == cv2.EVENT_MOUSEMOVE:
        point = [x, y]
        print(point)

cv2.namedWindow('RGB')
cv2.setMouseCallback('RGB', RGB)

cap = cv2.VideoCapture(r'D:\Model\helmet detection\he2.mp4')

count = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break
    count += 1
    if count % 3 != 0:
        continue

    frame = cv2.resize(frame, (1020, 500))

    results = model.predict(frame, stream=True)  # ✅ Stream=True for efficiency in video

    for result in results:
        boxes = result.boxes
        for box in boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            cls_id = int(box.cls[0])
            label = class_list[cls_id] if cls_id < len(class_list) else "Unknown"
            
            cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 2)
            cvzone.putTextRect(frame, f'{label}', (x1, y1), 1, 1)

    cv2.imshow("RGB", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 416x800 5 helmets, 596.1ms
# Speed: 19.2ms preprocess, 596.1ms inference, 14.2ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 464.0ms
# Speed: 10.2ms preprocess, 464.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 6 helmets, 463.3ms
# Speed: 5.5ms preprocess, 463.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 456.1ms
# Speed: 4.7ms preprocess, 456.1ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 498.0ms
# Speed: 4.4ms preprocess, 498.0ms inference, 6.6ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 700.3ms
# Speed: 6.5ms preprocess, 700.3ms inference, 6.2ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 5 helmets, 702.3ms
# Speed: 9.5ms preprocess, 702.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 800)
#
# 0: 416x800 4 helmets, 568.3ms
# ...
