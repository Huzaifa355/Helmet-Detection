# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.131 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.8/112.6 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -qe ultralytics

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.25M/6.25M [00:00<00:00, 131MB/s]
# Ultralytics 8.3.131 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 104k/104k [00:00<00:00, 152MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 57.7ms
# Speed: 12.2ms preprocess, 57.7ms inference, 355.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  Classroom  'Colab Notebooks'  'My Drive'   training_data.zip

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/training_data.zip
# Out:
# /content/datasets
# Archive:  /content/gdrive/MyDrive/training_data.zip
#    creating: training_data/images/
#    creating: training_data/images/training/
#   inflating: training_data/images/training/person_0.jpg
#   inflating: training_data/images/training/person_1.jpg
#   inflating: training_data/images/training/person_10.jpg
#   inflating: training_data/images/training/person_11.jpg
#   inflating: training_data/images/training/person_12.jpg
#   inflating: training_data/images/training/person_13.jpg
#   inflating: training_data/images/training/person_14.jpg
#   inflating: training_data/images/training/person_15.jpg
#   inflating: training_data/images/training/person_16.jpg
#   inflating: training_data/images/training/person_2.jpg
#   inflating: training_data/images/training/person_20.jpg
#   inflating: training_data/images/training/person_21.jpg
#   inflating: training_data/images/training/person_22.jpg
#   inflating: training_data/images/training/person_23.jpg
# ...

# %% [markdown]
# ## Custom Training

# %%
# %cd /content/datasets/training_data

# Move labels from images/train/ to labels/train/
# !mv images/train/*.txt labels/train/

# Move labels from images/val/ to labels/val/
# !mv images/val/*.txt labels/val/
# Out:
# /content/datasets/training_data
# mv: cannot stat 'images/train/*.txt': No such file or directory
# mv: cannot stat 'images/val/*.txt': No such file or directory

# %%
# !ls /content/datasets/training_data/images/train/*.jpg  # Should list files
# Out:
# /content/datasets/training_data/images/train/person_0.jpg
# /content/datasets/training_data/images/train/person_10.jpg
# /content/datasets/training_data/images/train/person_11.jpg
# /content/datasets/training_data/images/train/person_12.jpg
# /content/datasets/training_data/images/train/person_13.jpg
# /content/datasets/training_data/images/train/person_14.jpg
# /content/datasets/training_data/images/train/person_15.jpg
# /content/datasets/training_data/images/train/person_16.jpg
# /content/datasets/training_data/images/train/person_1.jpg
# /content/datasets/training_data/images/train/person_20.jpg
# /content/datasets/training_data/images/train/person_21.jpg
# /content/datasets/training_data/images/train/person_22.jpg
# /content/datasets/training_data/images/train/person_23.jpg
# /content/datasets/training_data/images/train/person_24.jpg
# /content/datasets/training_data/images/train/person_25.jpg
# /content/datasets/training_data/images/train/person_26.jpg
# ...

# %%
# !ls /content/datasets/training_data/labels/train/*.txt  # Should list files
# Out:
# /content/datasets/training_data/labels/train/classes.txt
# /content/datasets/training_data/labels/train/person_0.txt
# /content/datasets/training_data/labels/train/person_10.txt
# /content/datasets/training_data/labels/train/person_11.txt
# /content/datasets/training_data/labels/train/person_12.txt
# /content/datasets/training_data/labels/train/person_13.txt
# /content/datasets/training_data/labels/train/person_14.txt
# /content/datasets/training_data/labels/train/person_15.txt
# /content/datasets/training_data/labels/train/person_16.txt
# /content/datasets/training_data/labels/train/person_1.txt
# /content/datasets/training_data/labels/train/person_20.txt
# /content/datasets/training_data/labels/train/person_21.txt
# /content/datasets/training_data/labels/train/person_22.txt
# /content/datasets/training_data/labels/train/person_23.txt
# /content/datasets/training_data/labels/train/person_24.txt
# /content/datasets/training_data/labels/train/person_25.txt
# ...

# %%
# !find . -maxdepth 3 -type f -name "data.yaml"
# Out:
# ./datasets/training_data/data.yaml

# %%
# !ls /content/datasets/training_data
# Expected output: data.yaml, images/, labels/
# Out:
# data.yaml  images  labels

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=./datasets/training_data/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# Ultralytics 8.3.131 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
